# %%
import pandas as pd

# %%
data=pd.read_csv("Salary_dataset.csv")
data.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
data.drop("Unnamed: 0", axis=1, inplace=True)
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
x=data.iloc[:,:-1]
x.head()
# Out:
#    YearsExperience
# 0              1.2
# 1              1.4
# 2              1.6
# 3              2.1
# 4              2.3

# %%
y = data["Salary"]
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
data.corr()*100
# Out:
#                  YearsExperience      Salary
# YearsExperience       100.000000   97.824162
# Salary                 97.824162  100.000000

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2)
x_train.shape
# Out:
# (24, 1)

# %%
y_train.shape
# Out:
# (24,)

# %%
x_test.shape
# Out:
# (6, 1)

# %%
y_test.shape
# Out:
# (6,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train, y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
model.predict([[1.2]])
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36552.07458273])

# %%
y_pred=model.predict(x_test)

# %%
r2_score(y_test, y_pred) *100
# Out:
# 96.2312959210703

# %%
plt.scatter(x_train, y_train, color="green", label="Training Data")
plt.scatter(x_test, y_test, color="blue", label="Training Data")
plt.plot(x_test, model.predict(x_test), color="red", label="Best fit Line")
plt.legend()
plt.show()

# %%
plt.scatter(x_train, y_train, color="green", label="Training Data")
plt.scatter(x_test, y_test, color="blue", label="Training Data")
plt.plot(x_train, model.predict(x_train), color="red", label="Best fit Line")
plt.legend()
plt.show()

# %%
evaluation=pd.DataFrame({"Actual Value" : y_test, "predicted Value" : y_pred, "bias/Error" : y_test - y_pred})
evaluation
# Out:
#     Actual Value  predicted Value    bias/Error
# 4        39892.0     46739.646719  -6847.646719
# 18       81364.0     81006.934813    357.065187
# 23      113813.0    102308.222007  11504.777993
# 2        37732.0     40256.646269  -2524.646269
# 26      116970.0    114348.079986   2621.920014
# 1        46206.0     38404.360426   7801.639574

# %%
data=pd.read_csv("score.csv")
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
x=data.iloc[:,:-1]
x.head()
# Out:
#    Hours
# 0    2.5
# 1    5.1
# 2    3.2
# 3    8.5
# 4    3.5

# %%
y=data["Scores"]
y
# Out:
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
data.corr() *100
# Out:
#              Hours      Scores
# Hours   100.000000   97.619066
# Scores   97.619066  100.000000

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2)
x_train.shape
# Out:
# (20, 1)

# %%
y_train.shape
# Out:
# (20,)

# %%
x_test.shape
# Out:
# (5, 1)

# %%
y_test.shape
# Out:
# (5,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
model.predict([[2.5]])
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([26.82650141])

# %%
y_pred=model.predict(x_test)

# %%
r2_score(y_test, y_pred) *100
# Out:
# 97.3876486294993

# %%
plt.scatter(x_train, y_train, color="red", label="Training Data")
plt.scatter(x_test, y_test, color="blue", label="Testing Data")
plt.plot(x_test, model.predict(x_test), color="green", label="Best fit Line")
plt.legend()
plt.show()

# %%
evaluation=pd.DataFrame({"Actual Value": y_test, "Predict Value": y_pred, "Bias/Error value": y_test-y_pred})
evaluation
# Out:
#     Actual Value  Predict Value  Bias/Error value
# 12            41      46.660382         -5.660382
# 17            24      20.876337          3.123663
# 6             88      93.270003         -5.270003
# 8             81      84.344756         -3.344756
# 15            95      90.294921          4.705079
